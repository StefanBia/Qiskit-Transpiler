# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.circuit.library import RYGate, RZGate, CXGate

qubits = QuantumRegister(4, 'q')
clbits = ClassicalRegister(2, 'c')
qc = QuantumCircuit(qubits, clbits)

new_qc = QuantumCircuit(4, 2)

qc.append(RYGate(1.234), [0])
qc.append(CXGate(), [0, 1])
qc.append(RZGate(0.567), [1])

qc.x(0)
qc.measure(0, 0)
# for instruction in qc.data:
#     print(instruction)
#     print(instruction.operation)
#     for qubit in instruction.qubits:
#         idx = qc.find_bit(qubit).index
#         print(idx)

for instruction in qc.data:
    op = instruction.operation
    qubits = [qc.find_bit(qubit).index for qubit in instruction.qubits]
    cbits = [qc.find_bit(cbit).index for cbit in instruction.clbits]
    print(f"Operation: {op}, Qubits: {qubits}, Classical bits: {cbits}")
    
    new_qc.append(op, qubits, cbits)

qc.draw(output='mpl')
# Out:
# Operation: Instruction(name='ry', num_qubits=1, num_clbits=0, params=[1.234]), Qubits: [0], Classical bits: []
# Operation: Instruction(name='cx', num_qubits=2, num_clbits=0, params=[]), Qubits: [0, 1], Classical bits: []
# Operation: Instruction(name='rz', num_qubits=1, num_clbits=0, params=[0.567]), Qubits: [1], Classical bits: []
# Operation: Instruction(name='x', num_qubits=1, num_clbits=0, params=[]), Qubits: [0], Classical bits: []
# Operation: Instruction(name='measure', num_qubits=1, num_clbits=1, params=[]), Qubits: [0], Classical bits: [0]

# %%
new_qc.draw(output='mpl')

# %%
qc = QuantumCircuit(2,2)
qc.x(0)
qc.measure(1,0)
qc.swap(0,1)
qc.measure(1,1)

qc.draw(output='mpl')

# %%
from qiskit_aer import AerSimulator
simulator = AerSimulator()

job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts(qc)
print(counts)
# Out:
# {'10': 1024}
